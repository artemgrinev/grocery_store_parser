# %%
import pandas as pd

# %%
# продукты магазина О'кей
pd.read_csv('..\csv\okey.csv', delimiter=',')
# Out:
#      market_name                       domain  product_id  \
# 0           okey  https://www.okeydostavka.ru       41952
# 1           okey  https://www.okeydostavka.ru       41953
# 2           okey  https://www.okeydostavka.ru       41959
# 3           okey  https://www.okeydostavka.ru       42601
# 4           okey  https://www.okeydostavka.ru       42612
# ...          ...                          ...         ...
# 3784        okey  https://www.okeydostavka.ru      935613
# 3785        okey  https://www.okeydostavka.ru      850276
# 3786        okey  https://www.okeydostavka.ru      850327
# 3787        okey  https://www.okeydostavka.ru      871252
# 3788        okey  https://www.okeydostavka.ru      874583
#
#                                           product_name   price is_available  \
# 0                  Говядина вырезка п/ф охлажденный кг  1263.0            1
# 1                   Свинина вырезка п/ф охлажденный кг   491.9            1
# ...
